# %%
# This code updates the current clusters
# It assumes we already have a mapping which comes from cluster_mapping_04192018.csv
# Then it takes this and any correction, and outputs a new file with the corresponding clusters
# %matplotlib inline
import re
from fuzzywuzzy import fuzz
import matplotlib.pyplot as plt

import datetime
from dateutil import parser
from geopandas import GeoDataFrame
import pandas as pd
import numpy as np
from shapely.geometry import Point

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
# Out:
# /Users/sergiocamelo/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Load the data
data_clusters = pd.read_csv('/Users/sergiocamelo/Dropbox/Sergio-Joann/Names/Decisions/cluster_mapping_04192018.csv')

# %%
# Create a dictionary
clusters = {}
names = data_clusters['Buyer Name'].values
keys = data_clusters['cluster'].values
names_l = [str(n).lower() for n in names]
names_l = [n.strip() for n in names_l]
names_l = [re.sub('\s+', ' ', n) for n in names_l]
names_s = names_l
for i,n in enumerate(names_l):
    clusters[n] = keys[i]

# %%
# Get new names from dataset and check what is missing (if there is anything)
buyer_data = pd.read_csv('/Users/sergiocamelo/Dropbox/Sergio-Joann/20180412_Unilever_Main_Buyer_Progress_Data-CLEAN.csv')
buyer_data = buyer_data[['Member ID','Buyer Type','Buyer Name','Plot Nr']].copy()
buyer_data = buyer_data.rename(index=str, columns={'Member ID':"id", 'Buyer Type':"type", "Buyer Name":"buyer_name", 'Plot Nr':"plot", 'FFB Last Sold Date':"last_sold"})

all_names = buyer_data['buyer_name'].values
all_names = [str(n).lower() for n in all_names]
all_names = [n.strip() for n in all_names]
all_names = [re.sub('\s+', ' ', n) for n in all_names]
print(list(set(all_names) - set(names_l)))
print(list(set(names_l) - set(all_names)))
new_names = list(set(names_l) - set(all_names))
# Out:
# ['irwan simamora (spd) (nhr)', 'skip', 'danru', 'tidak tahu nama do, toke pak jukri (pks nhr)', 'irwan simamora (sbd)(nhr)', 'ggk ( gagok)', 'yp', 'sbd ( pabrik nhr )', 'ngamprah', 'do rgn', 'lagino', 'tj(pabrik skip)', 'irwan simamora (spd)(nhr)', 'saritok', 'gagok( ggk)', 'ramp blok e', 'tj rudi', 'sijul', 'cv. 3ym', 'ggk (gagok)', 'koperasi danau rambai', 'danau rambai', 'rgn', 'buah sendiri', 'do', 'bim', 'akhhi', 'kud sember bahagia', 'gagok (ggk)', 'do rgn (suroso)', 'pn ( pelangi nusantara)', 'sup do yp', 'ggk udin', 'pt bim', 'tj ( dandru )', 'tratama', 'mustar', 'asiong', 'sarito', 'pt. nat', 'nuriyanto', 'pt.harpena', 'nhr. skip', 'pabrik bim', 'pt. nad', 'spb tj', 'tinus', 'metto', 'yp(pabrik nhr)', 'sk (irwan)', 'jon. s', 'koperasi sejahtera', 'yp sei akar (pt.nhr siberida)', 'cv 3 ym', 'udin ggk', 'jhon simarmata', 'satpam pabrik (tj)', 'abp', 'sukat abadi', 'kud', '(null)', 'rj', 'darmin', 'pt. arvena', 'sk 01', 'do samson', 'pt. inecda', 'nts', 'jl', 'koperasi sumber bahagia', 'rudi (tj)', 'ac ( pabrik skip)', 'do tj (rudi)', 'sub do', 'tj ggk', 'pt. riau agri', 'srj', 'sub tj', 'pt. meganusa inti sawit', '(satria) ggk', 'pt(skip)', 'drj', 'kr 907 pt.nhr', 'do aw', 'ramasong', 'among', 'sastro sinaga', 'pt. nhr', 'tidak tau spb', 'sud do tj', 'pt. harpena', 'iwan simamora', 'suroso', 'bang irwan (nhr)', 'nhr', 'pt.mnis', 'rgn ( pabrik skip)', 'mbs', 'pt.bim', 'yp (nhr)', 'tj( pabrik skip)', 'pt. arpena', 'sub do tj ( eka )', 'master', 'tj ( pabrik skip)', 'k. u. d', 'riyadi (sip)', 'yp sei akar (pt. nhr seberida)', 'pt.nhr', 'yp (jul)', 'koperasi', 'pak zul', 'pt skip', 'ram bandar padang', 'irwan simamora (sk 01) pt.nhr', 'iwan simamora (sk)', 'ap pakpahan', 'rgn( pabrik skip)', 'setiarno', 'do zul pks nhr', 'anto (tj)', 'satpam di pabrik', 'mp', 'do tj ( dandru )', 'cv. tsr', 'suroso (rgn)', 'ac', 'nama pembeli atau do tidak terekam penjualan ke pt. nhr.', 'ai', 'ip', 'ak', 'satpam', 'cv sawit sejahtera', 'kud danau rambai jaya', 'as', 'sub do ( ggk )', 'jl sungai akar', 'do irwan', 'tj ( anto)', 'pt sekip', 'pabrik kelapa sawit bss', 'pt. berkat sawit sejahtera', 'ggk ( gaguk)', 'nat', 'pt. bss', 'do.rgn', 'do sb', 'do tj', 'rgn (suroso)', 'tidak tahu do dibawa pak jukri (pks nhr)', 'koperasi_tunas harapan', 'yp ( pks nhr)', 'ggk ()', 'aon', 'pt. skip', 'yp( pabrik skip)', 'surso', 'pt nat', 'slamat', 'tsr', 'pt. bim', 'ggk (gaguk)', 'gaguk(ggk)', 'yp sei akar (pt. nhr siberida)', 'harpena', 'kr', 'udin (ggk)', 'kerke', 'ggk( gagok)', 'yp(di pabrik nhr)', 'blok e', 'blok b']
# []

# %%
# For the moment I am only considering 3 - Middleman/Agent

# %%
# For each row of the buyers file, I get the cluster and then construct a dataset with this
def cluster_row(row):
    name = row['buyer_name']
    name = str(name).lower()
    name = name.strip()
    name = re.sub('\s+', ' ', name)
    if name in clusters.keys():
        return clusters[name]
    else:
        return float('nan')

buyer_data['cluster'] = buyer_data.apply(cluster_row, axis=1)

# %%
# We make some corrections
corrections_file = pd.read_csv('/Users/sergiocamelo/Dropbox/Sergio-Joann/Names/Decisions/Changes/180520_cluster_changes_comb.csv')
corrections_file = corrections_file.rename(index=str, columns={'Farmer_ID':"id", 'Farmer_plot':"plot"})

# Left join the datasets
corrected_file = pd.merge(buyer_data,corrections_file, how='left')

# Make the corrections
max_cluster = corrected_file.cluster.max()
for index,row in corrected_file.iterrows():
    if pd.notnull(row['change_cluster']):
        corrected_file.loc[index,'cluster'] = row['change_cluster']
    elif pd.notnull(row['new_cluster']):
        corrected_file.loc[index,'cluster'] = row['new_cluster'] + max_cluster
corrected_file = corrected_file[['id','type','buyer_name','plot','cluster']]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-9c81368355e2> in <module>()
#       1 # We make some corrections
# ----> 2 corrections_file = pd.read_csv('/Users/sergiocamelo/Dropbox/Sergio-Joann/Names/Decisions/180520_cluster_changes_comb.csv')
#       3 corrections_file = corrections_file.rename(index=str, columns={'Farmer_ID':"id", 'Farmer_plot':"plot"})
#       4
#       5 # Left join the datasets
#
# /Users/sergiocamelo/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# /Users/sergiocamelo/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     313
#     314     # Create the parser.
# --> 315     parser = TextFileReader(filepath_or_buffer, **kwds)
#     316
#     317     if (nrows is not None) and (chunksize is not None):
#
# /Users/sergiocamelo/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     643             self.options['has_index_names'] = kwds['has_index_names']
#     644
# --> 645         self._make_engine(self.engine)
#     646
#     647     def close(self):
#
# /Users/sergiocamelo/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     797     def _make_engine(self, engine='c'):
#     798         if engine == 'c':
# --> 799             self._engine = CParserWrapper(self.f, **self.options)
#     800         else:
#     801             if engine == 'python':
#
# /Users/sergiocamelo/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1211         kwds['allow_leading_cols'] = self.index_col is not False
#    1212
# -> 1213         self._reader = _parser.TextReader(src, **kwds)
#    1214
#    1215         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3427)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6861)()
#
# IOError: File /Users/sergiocamelo/Dropbox/Sergio-Joann/Names/Decisions/180520_cluster_changes_comb.csv does not exist

# %%
corrected_file.to_csv('/Users/sergiocamelo/Dropbox/Sergio-Joann/Names/Decisions/farmer_cluster_mappings_04222018.csv', index=False)

# %%
corrected_file
# Out:
#                 id                 type               buyer_name  plot  \
# 0     F14040190001  3 - Middleman/Agent                     Ijul     1
# 1     F14040190002  3 - Middleman/Agent                    Hasri     1
# 2     F14040190003  3 - Middleman/Agent                      Sam     1
# 3     F14040190004  3 - Middleman/Agent                     Asri     1
# 4     F14040190005  3 - Middleman/Agent                     Amin     1
# 5     F14040190006  3 - Middleman/Agent                    Ujang     1
# 6     F14040190007  3 - Middleman/Agent                    Giran     1
# 7     F14040190009  3 - Middleman/Agent                    Kamin     1
# 8     F14040190010  3 - Middleman/Agent                    Masri     1
# 9     F14040190012  3 - Middleman/Agent                     Agus     1
# 10    F14040190013  3 - Middleman/Agent                   Slamet     1
# 11    F14040190016  3 - Middleman/Agent                   Bujang     1
# 12    F14040190017  3 - Middleman/Agent                     Asis     1
# 13    F14040190019  3 - Middleman/Agent                 Pranyoto     1
# 14    F14040190020  3 - Middleman/Agent                 Rohayati     1
# 15    F14040190021  3 - Middleman/Agent                  Prayoto     1
# 16    F14040190022  3 - Middleman/Agent                    Giran     1
# 17    F14040190023  3 - Middleman/Agent                   Boimin     1
# 18    F14040190024  3 - Middleman/Agent                     Asri     1
# 19    F14040190025  3 - Middleman/Agent                      Adi     1
# 20    F14040190026  3 - Middleman/Agent                    Giran     1
# 21    F14040190027  3 - Middleman/Agent                     Asri     1
# 22    F14040190028  3 - Middleman/Agent                    Giran     1
# 23    F14040190029  3 - Middleman/Agent                     Asri     1
# 24    F14040190030  3 - Middleman/Agent                     Amin     1
# 25    F14040190031  3 - Middleman/Agent                  Samiudi     1
# 26    F14040190032  3 - Middleman/Agent               Agus Yanto     1
# 27    F14040190008  3 - Middleman/Agent                   Juahir     1
# 28    F14040190015  3 - Middleman/Agent                     Amin     1
# 29    F14040190018  3 - Middleman/Agent                     Amin     1
# ...            ...                  ...                      ...   ...
# 4112  F14020060347  3 - Middleman/Agent                      Edi     1
# 4113  F14020060348  3 - Middleman/Agent                      Edi     1
# 4114  F14020060349  3 - Middleman/Agent                    Fendi     1
# 4115  F14020060350  3 - Middleman/Agent                    Pendi     1
# 4116  F14020060351  3 - Middleman/Agent                    Fendi     1
# 4117  F14020060352  3 - Middleman/Agent                    Fendi     1
# 4118  F14020060353  3 - Middleman/Agent                    Fendi     1
# 4119  F14020060355  3 - Middleman/Agent                    Pendi     1
# 4120  F14020060356  3 - Middleman/Agent                      Edi     1
# 4121  F14020060358  3 - Middleman/Agent                     Deni     1
# 4122  F14020060364  3 - Middleman/Agent                    Fendi     1
# 4123  F14020060365  3 - Middleman/Agent                    Fendi     1
# 4124  F14020060366  3 - Middleman/Agent                    Fendi     1
# 4125  F14020060367  3 - Middleman/Agent                    Pendi     1
# 4126  F14020060368  3 - Middleman/Agent                    Pendi     1
# 4127  F14020060369  3 - Middleman/Agent                    Pendi     1
# 4128  F14020060403  3 - Middleman/Agent                    Pendi     1
# 4129  F14020060406  3 - Middleman/Agent                    Fendi     1
# 4130  F14020060411  3 - Middleman/Agent                    Fendi     1
# 4131  F14020060412  3 - Middleman/Agent                    Fendi     1
# 4132  F14020060426  3 - Middleman/Agent                  Ngatinu     1
# 4133  F14020060427  3 - Middleman/Agent                   Viktor     1
# 4134  F14020060428  3 - Middleman/Agent                   Viktor     1
# 4135  F14020060428  3 - Middleman/Agent                  Ngatino     2
# 4136  F14020060429  3 - Middleman/Agent                  Ngatino     1
# 4137  F14020060573    1 - Palm Oil Mill                  PT.MNIS     1
# 4138  F14020060574  3 - Middleman/Agent                   Piktor     1
# 4139  F14020060619  3 - Middleman/Agent                    Sudar     1
# 4140  F14020060620    1 - Palm Oil Mill  PT. Meganusa Inti Sawit     1
# 4141  F14020060621  3 - Middleman/Agent                     Dedy     1
#
#       cluster
# 0       373.0
# 1       181.0
# 2        20.0
# 3       181.0
# 4       175.0
# 5       150.0
# 6       350.0
# 7       175.0
# 8       181.0
# 9       108.0
# 10      183.0
# 11      150.0
# 12      173.0
# 13      206.0
# 14      518.0
# 15      206.0
# 16      350.0
# 17      307.0
# 18      181.0
# 19      187.0
# 20      350.0
# 21      181.0
# 22      350.0
# 23      181.0
# 24      175.0
# 25       20.0
# 26      111.0
# 27      402.0
# 28      175.0
# 29      175.0
# ...       ...
# 4112    164.0
# 4113    164.0
# 4114     55.0
# 4115     55.0
# 4116     55.0
# 4117     55.0
# 4118     55.0
# 4119     55.0
# 4120    164.0
# 4121    330.0
# 4122     55.0
# 4123     55.0
# 4124     55.0
# 4125     55.0
# 4126     55.0
# 4127     55.0
# 4128     55.0
# 4129     55.0
# 4130     55.0
# 4131     55.0
# 4132      4.0
# 4133     10.0
# 4134     10.0
# 4135      4.0
# 4136      4.0
# 4137      NaN
# 4138     10.0
# 4139    661.0
# 4140      NaN
# 4141    328.0
#
# [4142 rows x 5 columns]
