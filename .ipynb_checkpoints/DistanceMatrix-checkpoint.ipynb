# %%
# Key for Google API
key = 'AIzaSyC_9-JJK9w-cvWaJT7SPQLLlFvvhhuRss4'

# %%
# %matplotlib inline

import datetime
from dateutil import parser


from geopandas import GeoDataFrame
import pandas as pd
import numpy as np
from shapely.geometry import Point

# Read data
df = pd.read_csv('positions.csv')
# Out:
# /Users/sergiocamelo/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# format lat longs into a list
sentence = np.char.array([str(a) for a in df.lat.values])+','+np.char.array([str(a) for a in df.lon.values])
sentence = '|'.join(sentence)
sentence
# Out:
# '-0.413457,102.582787|-0.421501,102.579102|-0.427449,102.578453|-0.422377,102.578857|-0.424441,102.576378|-0.682804,102.489128|-0.702206,102.508072|-0.695469,102.539223|-0.684568,102.543175|-0.708039,102.566833'

# %%
# Construct query
query = ('https://maps.googleapis.com/maps/api/distancematrix/json?origins=' + sentence + 
         '&destinations=' + sentence + '&key=' + key)

# %%
# Query the API
import urllib
f = urllib.urlopen(query)
myfile = f.read()
# Out:
# {
#    "destination_addresses" : [
#       "Jl. Lintas Rengat - Rumbai Jaya, Sungai Raya, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Jl. Lintas Tim., Ringin, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29371, Indonesia",
#       "Unnamed Road, Ringin, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29371, Indonesia",
#       "Unnamed Road, Belimbing, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29355, Indonesia",
#       "Unnamed Road, Belimbing, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29355, Indonesia",
#       "Unnamed Road, Belimbing, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29355, Indonesia"
#    ],
#    "origin_addresses" : [
#       "Jl. Lintas Rengat - Rumbai Jaya, Sungai Raya, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Unnamed Road, Rengat, Kabupaten Indragiri Hulu, Riau, Indonesia",
#       "Jl. Lintas Tim., Ringin, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29371, Indonesia",
#       "Unnamed Road, Ringin, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29371, Indonesia",
#       "Unnamed Road, Belimbing, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29355, Indonesia",
#       "Unnamed Road, Belimbing, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29355, Indonesia",
#       "Unnamed Road, Belimbing, Batang Gansal, Kabupaten Indragiri Hulu, Riau 29355, Indonesia"
#    ],
#    "rows" : [
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "12.6 km",
#                   "value" : 12639
#                },
#                "duration" : {
#                   "text" : "28 mins",
#                   "value" : 1708
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "12.6 km",
#                   "value" : 12615
#                },
#                "duration" : {
#                   "text" : "28 mins",
#                   "value" : 1704
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "12.6 km",
#                   "value" : 12619
#                },
#                "duration" : {
#                   "text" : "28 mins",
#                   "value" : 1705
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "12.4 km",
#                   "value" : 12361
#                },
#                "duration" : {
#                   "text" : "28 mins",
#                   "value" : 1656
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "67.9 km",
#                   "value" : 67856
#                },
#                "duration" : {
#                   "text" : "1 hour 30 mins",
#                   "value" : 5394
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "69.7 km",
#                   "value" : 69685
#                },
#                "duration" : {
#                   "text" : "1 hour 32 mins",
#                   "value" : 5542
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "75.2 km",
#                   "value" : 75191
#                },
#                "duration" : {
#                   "text" : "1 hour 46 mins",
#                   "value" : 6367
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.3 km",
#                   "value" : 76348
#                },
#                "duration" : {
#                   "text" : "1 hour 47 mins",
#                   "value" : 6399
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "78.7 km",
#                   "value" : 78684
#                },
#                "duration" : {
#                   "text" : "1 hour 51 mins",
#                   "value" : 6644
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "12.6 km",
#                   "value" : 12639
#                },
#                "duration" : {
#                   "text" : "29 mins",
#                   "value" : 1741
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "25 m",
#                   "value" : 25
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 5
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "20 m",
#                   "value" : 20
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 4
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "0.3 km",
#                   "value" : 279
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 53
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "69.1 km",
#                   "value" : 69055
#                },
#                "duration" : {
#                   "text" : "1 hour 39 mins",
#                   "value" : 5920
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "70.9 km",
#                   "value" : 70884
#                },
#                "duration" : {
#                   "text" : "1 hour 41 mins",
#                   "value" : 6069
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.4 km",
#                   "value" : 76390
#                },
#                "duration" : {
#                   "text" : "1 hour 55 mins",
#                   "value" : 6894
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.5 km",
#                   "value" : 77547
#                },
#                "duration" : {
#                   "text" : "1 hour 55 mins",
#                   "value" : 6926
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "79.9 km",
#                   "value" : 79883
#                },
#                "duration" : {
#                   "text" : "2 hours 0 mins",
#                   "value" : 7170
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "12.6 km",
#                   "value" : 12615
#                },
#                "duration" : {
#                   "text" : "29 mins",
#                   "value" : 1737
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "25 m",
#                   "value" : 25
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 5
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "5 m",
#                   "value" : 5
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 1
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "0.3 km",
#                   "value" : 254
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 48
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "69.0 km",
#                   "value" : 69030
#                },
#                "duration" : {
#                   "text" : "1 hour 39 mins",
#                   "value" : 5916
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "70.9 km",
#                   "value" : 70860
#                },
#                "duration" : {
#                   "text" : "1 hour 41 mins",
#                   "value" : 6064
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.4 km",
#                   "value" : 76365
#                },
#                "duration" : {
#                   "text" : "1 hour 55 mins",
#                   "value" : 6889
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.5 km",
#                   "value" : 77523
#                },
#                "duration" : {
#                   "text" : "1 hour 55 mins",
#                   "value" : 6921
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "79.9 km",
#                   "value" : 79859
#                },
#                "duration" : {
#                   "text" : "1 hour 59 mins",
#                   "value" : 7165
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "12.6 km",
#                   "value" : 12619
#                },
#                "duration" : {
#                   "text" : "29 mins",
#                   "value" : 1738
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "20 m",
#                   "value" : 20
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 4
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "5 m",
#                   "value" : 5
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 1
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "0.3 km",
#                   "value" : 259
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 49
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "69.0 km",
#                   "value" : 69035
#                },
#                "duration" : {
#                   "text" : "1 hour 39 mins",
#                   "value" : 5916
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "70.9 km",
#                   "value" : 70864
#                },
#                "duration" : {
#                   "text" : "1 hour 41 mins",
#                   "value" : 6065
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.4 km",
#                   "value" : 76370
#                },
#                "duration" : {
#                   "text" : "1 hour 55 mins",
#                   "value" : 6890
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.5 km",
#                   "value" : 77527
#                },
#                "duration" : {
#                   "text" : "1 hour 55 mins",
#                   "value" : 6922
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "79.9 km",
#                   "value" : 79863
#                },
#                "duration" : {
#                   "text" : "1 hour 59 mins",
#                   "value" : 7166
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "12.4 km",
#                   "value" : 12361
#                },
#                "duration" : {
#                   "text" : "28 mins",
#                   "value" : 1689
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "0.3 km",
#                   "value" : 279
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 53
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "0.3 km",
#                   "value" : 254
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 48
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "0.3 km",
#                   "value" : 259
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 49
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "68.8 km",
#                   "value" : 68776
#                },
#                "duration" : {
#                   "text" : "1 hour 38 mins",
#                   "value" : 5867
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "70.6 km",
#                   "value" : 70606
#                },
#                "duration" : {
#                   "text" : "1 hour 40 mins",
#                   "value" : 6016
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.1 km",
#                   "value" : 76111
#                },
#                "duration" : {
#                   "text" : "1 hour 54 mins",
#                   "value" : 6841
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.3 km",
#                   "value" : 77269
#                },
#                "duration" : {
#                   "text" : "1 hour 55 mins",
#                   "value" : 6873
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "79.6 km",
#                   "value" : 79605
#                },
#                "duration" : {
#                   "text" : "1 hour 59 mins",
#                   "value" : 7117
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "67.6 km",
#                   "value" : 67587
#                },
#                "duration" : {
#                   "text" : "1 hour 32 mins",
#                   "value" : 5491
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "68.8 km",
#                   "value" : 68842
#                },
#                "duration" : {
#                   "text" : "1 hour 40 mins",
#                   "value" : 6020
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "68.8 km",
#                   "value" : 68818
#                },
#                "duration" : {
#                   "text" : "1 hour 40 mins",
#                   "value" : 6015
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "68.8 km",
#                   "value" : 68822
#                },
#                "duration" : {
#                   "text" : "1 hour 40 mins",
#                   "value" : 6016
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "68.6 km",
#                   "value" : 68563
#                },
#                "duration" : {
#                   "text" : "1 hour 39 mins",
#                   "value" : 5967
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "3.7 km",
#                   "value" : 3712
#                },
#                "duration" : {
#                   "text" : "6 mins",
#                   "value" : 385
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "9.2 km",
#                   "value" : 9218
#                },
#                "duration" : {
#                   "text" : "20 mins",
#                   "value" : 1210
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "10.4 km",
#                   "value" : 10375
#                },
#                "duration" : {
#                   "text" : "21 mins",
#                   "value" : 1243
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "12.7 km",
#                   "value" : 12711
#                },
#                "duration" : {
#                   "text" : "25 mins",
#                   "value" : 1487
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "69.9 km",
#                   "value" : 69853
#                },
#                "duration" : {
#                   "text" : "1 hour 34 mins",
#                   "value" : 5663
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "71.1 km",
#                   "value" : 71108
#                },
#                "duration" : {
#                   "text" : "1 hour 43 mins",
#                   "value" : 6193
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "71.1 km",
#                   "value" : 71084
#                },
#                "duration" : {
#                   "text" : "1 hour 43 mins",
#                   "value" : 6188
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "71.1 km",
#                   "value" : 71088
#                },
#                "duration" : {
#                   "text" : "1 hour 43 mins",
#                   "value" : 6189
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "70.8 km",
#                   "value" : 70830
#                },
#                "duration" : {
#                   "text" : "1 hour 42 mins",
#                   "value" : 6140
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "3.7 km",
#                   "value" : 3712
#                },
#                "duration" : {
#                   "text" : "8 mins",
#                   "value" : 476
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "7.1 km",
#                   "value" : 7061
#                },
#                "duration" : {
#                   "text" : "18 mins",
#                   "value" : 1071
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "8.2 km",
#                   "value" : 8218
#                },
#                "duration" : {
#                   "text" : "18 mins",
#                   "value" : 1104
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "10.6 km",
#                   "value" : 10554
#                },
#                "duration" : {
#                   "text" : "22 mins",
#                   "value" : 1348
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "75.4 km",
#                   "value" : 75359
#                },
#                "duration" : {
#                   "text" : "1 hour 48 mins",
#                   "value" : 6494
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.6 km",
#                   "value" : 76614
#                },
#                "duration" : {
#                   "text" : "1 hour 57 mins",
#                   "value" : 7023
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.6 km",
#                   "value" : 76589
#                },
#                "duration" : {
#                   "text" : "1 hour 57 mins",
#                   "value" : 7018
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.6 km",
#                   "value" : 76594
#                },
#                "duration" : {
#                   "text" : "1 hour 57 mins",
#                   "value" : 7019
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "76.3 km",
#                   "value" : 76335
#                },
#                "duration" : {
#                   "text" : "1 hour 56 mins",
#                   "value" : 6970
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "9.2 km",
#                   "value" : 9218
#                },
#                "duration" : {
#                   "text" : "22 mins",
#                   "value" : 1307
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "7.1 km",
#                   "value" : 7061
#                },
#                "duration" : {
#                   "text" : "19 mins",
#                   "value" : 1162
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1.4 km",
#                   "value" : 1414
#                },
#                "duration" : {
#                   "text" : "3 mins",
#                   "value" : 188
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "3.8 km",
#                   "value" : 3750
#                },
#                "duration" : {
#                   "text" : "7 mins",
#                   "value" : 432
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "76.5 km",
#                   "value" : 76516
#                },
#                "duration" : {
#                   "text" : "1 hour 49 mins",
#                   "value" : 6532
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.8 km",
#                   "value" : 77771
#                },
#                "duration" : {
#                   "text" : "1 hour 58 mins",
#                   "value" : 7061
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.7 km",
#                   "value" : 77747
#                },
#                "duration" : {
#                   "text" : "1 hour 58 mins",
#                   "value" : 7056
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.8 km",
#                   "value" : 77751
#                },
#                "duration" : {
#                   "text" : "1 hour 58 mins",
#                   "value" : 7057
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "77.5 km",
#                   "value" : 77493
#                },
#                "duration" : {
#                   "text" : "1 hour 57 mins",
#                   "value" : 7008
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "10.4 km",
#                   "value" : 10375
#                },
#                "duration" : {
#                   "text" : "22 mins",
#                   "value" : 1345
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "8.2 km",
#                   "value" : 8218
#                },
#                "duration" : {
#                   "text" : "20 mins",
#                   "value" : 1200
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1.4 km",
#                   "value" : 1414
#                },
#                "duration" : {
#                   "text" : "3 mins",
#                   "value" : 189
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "3.9 km",
#                   "value" : 3935
#                },
#                "duration" : {
#                   "text" : "7 mins",
#                   "value" : 433
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "78.9 km",
#                   "value" : 78853
#                },
#                "duration" : {
#                   "text" : "1 hour 53 mins",
#                   "value" : 6770
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "80.1 km",
#                   "value" : 80107
#                },
#                "duration" : {
#                   "text" : "2 hours 2 mins",
#                   "value" : 7300
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "80.1 km",
#                   "value" : 80083
#                },
#                "duration" : {
#                   "text" : "2 hours 2 mins",
#                   "value" : 7295
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "80.1 km",
#                   "value" : 80087
#                },
#                "duration" : {
#                   "text" : "2 hours 2 mins",
#                   "value" : 7296
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "79.8 km",
#                   "value" : 79829
#                },
#                "duration" : {
#                   "text" : "2 hours 1 min",
#                   "value" : 7247
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "12.7 km",
#                   "value" : 12711
#                },
#                "duration" : {
#                   "text" : "26 mins",
#                   "value" : 1583
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "10.6 km",
#                   "value" : 10554
#                },
#                "duration" : {
#                   "text" : "24 mins",
#                   "value" : 1438
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "3.8 km",
#                   "value" : 3750
#                },
#                "duration" : {
#                   "text" : "7 mins",
#                   "value" : 427
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "3.9 km",
#                   "value" : 3935
#                },
#                "duration" : {
#                   "text" : "7 mins",
#                   "value" : 433
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "1 m",
#                   "value" : 0
#                },
#                "duration" : {
#                   "text" : "1 min",
#                   "value" : 0
#                },
#                "status" : "OK"
#             }
#          ]
#       }
#    ],
#    "status" : "OK"
# }

# %%
# Format output
import json
output = json.loads(myfile)

# %%
def format_distance(d):
    sp = d.split(" ")
    value = float(sp[0])
    if sp[1] == u'km':
        value = value * 1000
    return value

def format_time(t):
    sp = t.split(" ")
    value = 0
    i = 0
    while i<len(sp):
        if sp[i+1]==u'min' or sp[i+1]==u'mins':
            value += float(sp[i])
        if sp[i+1]==u'hour' or sp[i+1]==u'hours':
            value += float(sp[i])*60
        i+=2
    return value

# %%
n = len(output['rows'])
distances = np.zeros([n,n])
times = np.zeros([n,n])
for i in range(n):
    for j in range(n):
        distances[i,j] = format_distance(output['rows'][i]['elements'][j]['distance']['text'])
        times[i,j] = format_time(output['rows'][i]['elements'][j]['duration']['text'])

# %%
times/distances
# Out:
# array([[ 1.        ,  0.00222222,  0.00222222,  0.00222222,  0.00225806,
#          0.00132548,  0.00131994,  0.00140957,  0.00140236,  0.00141042],
#        [ 0.00230159,  1.        ,  0.04      ,  0.05      ,  0.00333333,
#          0.00143271,  0.00142454,  0.00150524,  0.00148387,  0.00150188],
#        [ 0.00230159,  0.04      ,  1.        ,  0.2       ,  0.00333333,
#          0.00143478,  0.00142454,  0.00150524,  0.00148387,  0.00148936],
#        [ 0.00230159,  0.05      ,  0.2       ,  1.        ,  0.00333333,
#          0.00143478,  0.00142454,  0.00150524,  0.00148387,  0.00148936],
#        [ 0.00225806,  0.00333333,  0.00333333,  0.00333333,  1.        ,
#          0.00142442,  0.00141643,  0.00149803,  0.00148771,  0.00149497],
#        [ 0.00136095,  0.00145349,  0.00145349,  0.00145349,  0.00144315,
#          1.        ,  0.00162162,  0.00217391,  0.00201923,  0.0019685 ],
#        [ 0.00134478,  0.00144866,  0.00144866,  0.00144866,  0.00144068,
#          0.00216216,  1.        ,  0.00253521,  0.00219512,  0.00207547],
#        [ 0.00143236,  0.00152742,  0.00152742,  0.00152742,  0.00152031,
#          0.0023913 ,  0.00267606,  1.        ,  0.00214286,  0.00184211],
#        [ 0.00142484,  0.00151671,  0.00151866,  0.00151671,  0.00150968,
#          0.00211538,  0.00243902,  0.00214286,  1.        ,  0.00179487],
#        [ 0.00143219,  0.0015231 ,  0.0015231 ,  0.0015231 ,  0.00151629,
#          0.00204724,  0.00226415,  0.00184211,  0.00179487,  1.        ]])

# %%
# Read mill data
df_mills = pd.read_csv('mills.csv')
df_mills
# Out:
#                                     Name       lat         lon
# 0              PT Sugih Reksa Jaya (SRJ) -0.792917  102.596300
# 1                                PT SKIP -0.682690  102.501500
# 2                                 PT NHR -0.734611  102.525111
# 3           PT Berlian Inti Makmur (BIM) -0.722534  102.627397
# 4          PT Putra Keritang Sawit (PKS) -0.852778  102.655556
# 5                                 PT KAT -0.639439  102.492811
# 6                              PT Arvena -0.661142  102.344256
# 7                               PT Tasma -0.814667  102.189997
# 8           PT Swakarsa Sawit Raya (SSR) -0.487500  102.480000
# 9                PT Mega Nusa Inti Sawit -0.568614  102.309721
# 10        PT (Unknown name, east of BIM) -0.709042  102.659479
# 11  PT (Unknown name, northwest of SKIP) -0.493421  102.367501
# 12                      PTPN V Kota Lama -0.374578  102.384286

# %%
# format lat longs into a list
sentence_mills = np.char.array([str(a) for a in df_mills.lat.values])+','+np.char.array([str(a) for a in df_mills.lon.values])
sentence_mills = '|'.join(sentence_mills)
sentence_mills
# Out:
# '-0.792917,102.5963|-0.68269,102.5015|-0.734611,102.525111|-0.722534,102.627397|-0.852778,102.655556|-0.639439,102.492811|-0.661142,102.344256|-0.814666694,102.1899972|-0.4875,102.48|-0.568614,102.309721|-0.709042,102.659479|-0.493421,102.367501|-0.374578,102.384286'

# %%
# Construct query
query = ('https://maps.googleapis.com/maps/api/distancematrix/json?origins=' + sentence + 
         '&destinations=' + sentence_mills + '&key=' + key)
query
# Out:
# 'https://maps.googleapis.com/maps/api/distancematrix/json?origins=-0.413457,102.582787|-0.421501,102.579102|-0.427449,102.578453|-0.422377,102.578857|-0.424441,102.576378|-0.682804,102.489128|-0.702206,102.508072|-0.695469,102.539223|-0.684568,102.543175|-0.708039,102.566833&destinations=-0.792917,102.5963|-0.68269,102.5015|-0.734611,102.525111|-0.722534,102.627397|-0.852778,102.655556|-0.639439,102.492811|-0.661142,102.344256|-0.814666694,102.1899972|-0.4875,102.48|-0.568614,102.309721|-0.709042,102.659479|-0.493421,102.367501|-0.374578,102.384286&key=AIzaSyC_9-JJK9w-cvWaJT7SPQLLlFvvhhuRss4'

# %%
# Query the API
import urllib
f = urllib.urlopen(query)
myfile = f.read()
output_mills = json.loads(myfile)

# %%
output_mills
# Out:
# {u'destination_addresses': [],
#  u'error_message': u'You have exceeded your rate-limit for this API.',
#  u'origin_addresses': [],
#  u'rows': [],
#  u'status': u'OVER_QUERY_LIMIT'}

# %%
import math
import random
from gurobipy import *


# Callback - use lazy constraints to eliminate sub-tours

def subtourelim(model, where):
  if where == GRB.callback.MIPSOL:
    selected = []
    # make a list of edges selected in the solution
    for i in range(n):
      sol = model.cbGetSolution([model._vars[i,j] for j in range(n)])
      selected += [(i,j) for j in range(n) if sol[j] > 0.5]
    # find the shortest cycle in the selected edge list
    tour = subtour(selected)
    if len(tour) < n:
      # add a subtour elimination constraint
      expr = 0
      for i in range(len(tour)):
        for j in range(i+1, len(tour)):
          expr += model._vars[tour[i], tour[j]]
      model.cbLazy(expr <= len(tour)-1)


# Distance between two points

def distance(matrix, i, j):
  return matrix[i,j]


# Given a list of edges, finds the shortest subtour

def subtour(edges):
  visited = [False]*n
  cycles = []
  lengths = []
  selected = [[] for i in range(n)]
  for x,y in edges:
    selected[x].append(y)
  while True:
    current = visited.index(False)
    thiscycle = [current]
    while True:
      visited[current] = True
      neighbors = [x for x in selected[current] if not visited[x]]
      if len(neighbors) == 0:
        break
      current = neighbors[0]
      thiscycle.append(current)
    cycles.append(thiscycle)
    lengths.append(len(thiscycle))
    if sum(lengths) == n:
      break
  return cycles[lengths.index(min(lengths))]

# %%
n = len(output['rows'])

m = Model()


# Create variables

vars = {}
for i in range(n):
   for j in range(i+1):
     vars[i,j] = m.addVar(obj=distance(distances, i, j), vtype=GRB.BINARY,
                          name='e'+str(i)+'_'+str(j))
     vars[j,i] = vars[i,j]
   m.update()


# Add degree-2 constraint, and forbid loops

for i in range(n):
  m.addConstr(quicksum(vars[i,j] for j in range(n)) == 2)
  vars[i,i].ub = 0

m.update()


# Optimize model

m._vars = vars
m.params.LazyConstraints = 1
m.optimize(subtourelim)

solution = m.getAttr('x', vars)
selected = [(i,j) for i in range(n) for j in range(n) if solution[i,j] > 0.5]
assert len(subtour(selected)) == n
# Out:
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 10 rows, 55 columns and 100 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [1e+00, 8e+04]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [2e+00, 2e+00]
# Presolve removed 0 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 45 columns, 90 nonzeros
# Variable types: 0 continuous, 45 integer (45 binary)
#
# Root relaxation: objective 1.509250e+05, 14 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 161287.500    0   10          - 161287.500      -     -    0s
# *    0     0               0    176425.00000 176425.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 8
#
# Explored 0 nodes (28 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.764250000000e+05, best bound 1.764250000000e+05, gap 0.0%
